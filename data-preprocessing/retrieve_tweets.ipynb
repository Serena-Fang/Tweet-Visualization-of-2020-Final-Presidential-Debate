# %% [markdown]
# # Retrieve Tweets
#
# Takes a list of tweet IDs and outputs the full tweet dataset. When the script hits Twitter's API limit, it will automatically wait and restart after the appropriate amount of time. Because of the API rate limiting, this script could take up to a few hours.

# %%
import pandas as pd
import tweepy
import csv

# %%
# Insert your Twitter API key here

consumer_key = '0Msjs7CiwZBWm1lHYM56ZV7f5'
consumer_secret = 'HLT5Y2qXIAEuVUZKMJ4NzGpWKWlYOncUytsv68VNcmNRCJqZ6y'
access_token = '1457079615730724864-WAoI78DwmrXJXXUV5WkPZvsWnnjUdC'
access_secret = 'OPXY449ipD0kRENrhKXH4ysw0IYSbDeM6XclooYwhDUtp'

# %%
df = pd.read_csv('id_full.csv')

# %%
def retrieve_tweets(input_file, output_file):
    
    """
    Takes an input filename/path of tweetIDs and outputs the full tweet data to a csv
    """
    
    # Authorization with Twitter
    
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)
#     api = tweepy.API(auth, wait_on_rate_limit=False, wait_on_rate_limit_notify=False, retry_count=3, retry_delay=5, retry_errors=set([401, 404, 500, 503]))
    api = tweepy.API(auth, wait_on_rate_limit=False, retry_count=3, retry_delay=5, retry_errors=set([401, 404, 500, 503]))

    # Read input file

    df = pd.read_csv(input_file)

    # Create output file

    csvFile = open(output_file, 'w')
    csvWriter = csv.writer(csvFile)
    csvWriter.writerow(["text",
                        "created_at",
                        "geo",
                        "lang",
                        "place",
                        "coordinates",
                        "user.favourites_count",
                        "user.statuses_count",
                        "user.description",
                        "user.location",
                        "user.id",
                        "user.created_at",
                        "user.verified",
                        "user.following",
                        "user.url",
                        "user.listed_count",
                        "user.followers_count",
                        "user.default_profile_image",
                        "user.utc_offset",
                        "user.friends_count",
                        "user.default_profile",
                        "user.name",
                        "user.lang",
                        "user.screen_name",
                        "user.geo_enabled",
                        "user.profile_background_color",
                        "user.profile_image_url",
                        "user.time_zone",
                        "id",
                        "favorite_count",
                        "retweeted",
                        "source",
                        "favorited",
                        "retweet_count"])
    
    # Append tweets to output file

    for tweetid in df.iloc[:,0]:

        csvFile = open(output_file, 'a')

        csvWriter = csv.writer(csvFile)

        try:
            status = api.get_status(tweetid)
            csvWriter.writerow([status.text,
                                status.created_at,
                                status.geo,
                                status.lang,
                                status.place,
                                status.coordinates,
                                status.user.favourites_count,
                                status.user.statuses_count,
                                status.user.description,
                                status.user.location,
                                status.user.id,
                                status.user.created_at,
                                status.user.verified,
                                status.user.following,
                                status.user.url,
                                status.user.listed_count,
                                status.user.followers_count,
                                status.user.default_profile_image,
                                status.user.utc_offset,
                                status.user.friends_count,
                                status.user.default_profile,
                                status.user.name,
                                status.user.lang,
                                status.user.screen_name,
                                status.user.geo_enabled,
                                status.user.profile_background_color,
                                status.user.profile_image_url,
                                status.user.time_zone,
                                status.id,
                                status.favorite_count,
                                status.retweeted,
                                status.source,
                                status.favorited,
                                status.retweet_count])
        except Exception as e:
            print(e)
            pass

# %%
retrieve_tweets('id_22.csv', 'tweets_22.csv')
# Out:
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 34 - Sorry, that page does not exist.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 34 - Sorry, that page does not exist.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# Failed to send request: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# Failed to send request: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 34 - Sorry, that page does not exist.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 34 - Sorry, that page does not exist.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out. (read timeout=60)
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# Failed to send request: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# Failed to send request: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 34 - Sorry, that page does not exist.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out. (read timeout=60)
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out. (read timeout=60)
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# Failed to send request: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# Failed to send request: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out. (read timeout=60)
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 34 - Sorry, that page does not exist.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 34 - Sorry, that page does not exist.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# ...
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 34 - Sorry, that page does not exist.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# Failed to send request: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# Failed to send request: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 179 - Sorry, you are not authorized to see this status.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# 404 Not Found
# 144 - No status found with that ID.
# 403 Forbidden
# 63 - User has been suspended.
# 403 Forbidden
# 63 - User has been suspended.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-dd4d6aae6077> in <module>
# ----> 1 retrieve_tweets('id_22.csv', 'tweets_22.csv')
#
# <ipython-input-5-9a974a9ae030> in retrieve_tweets(input_file, output_file)
#      64
#      65         try:
# ---> 66             status = api.get_status(tweetid)
#      67             csvWriter.writerow([status.text,
#      68                                 status.created_at,
#
# /opt/anaconda3/lib/python3.7/site-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# /opt/anaconda3/lib/python3.7/site-packages/tweepy/api.py in get_status(self, id, **kwargs)
#     883                 'id', 'trim_user', 'include_my_retweet', 'include_entities',
#     884                 'include_ext_alt_text', 'include_card_uri'
# --> 885             ), id=id, **kwargs
#     886         )
#     887
#
# /opt/anaconda3/lib/python3.7/site-packages/tweepy/api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     247
#     248                 # Sleep before retrying request again
# --> 249                 time.sleep(retry_delay)
#     250                 retries_performed += 1
#     251
#
# KeyboardInterrupt:
